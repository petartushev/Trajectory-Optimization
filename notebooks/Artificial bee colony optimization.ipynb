# %%
import os
import time
import numpy as np
import pandas as pd
import random
import math

from copy import deepcopy
from six import add_metaclass
from abc import ABCMeta, abstractmethod
from scipy import optimize
from deap.benchmarks import schwefel

import matplotlib.pyplot as plt

import folium

# %%
trajectory1 = np.load( os.getcwd() + '/SampleTraj/Trj_0.npy' )
trajectory1 = pd.DataFrame(trajectory1)
trajectory1.columns = ['timestamp', 'latitude', 'longitude', 'altitude']
trajectory1 = trajectory1.drop_duplicates(subset=['latitude', 'longitude'], keep='first').to_numpy()


trajectory2 = np.load( os.getcwd() + '/SampleTraj/Trj_1.npy' )
trajectory2 = pd.DataFrame(trajectory2)
trajectory2.columns = ['timestamp', 'latitude', 'longitude', 'altitude']
trajectory2 = trajectory2.drop_duplicates(subset=['latitude', 'longitude'], keep='first').to_numpy()


trajectory3 = np.load( os.getcwd() + '/SampleTraj/Trj_2.npy' )
trajectory3 = pd.DataFrame(trajectory3)
trajectory3.columns = ['timestamp', 'latitude', 'longitude', 'altitude']
trajectory3 = trajectory3.drop_duplicates(subset=['latitude', 'longitude'], keep='first').to_numpy()

trajectory4 = np.load( os.getcwd() + '/SampleTraj/Trj_3.npy' )
trajectory4 = pd.DataFrame(trajectory4)
trajectory4.columns = ['timestamp', 'latitude', 'longitude', 'altitude']
trajectory4 = trajectory4.drop_duplicates(subset=['latitude', 'longitude'], keep='first').to_numpy()
# targetPoint = -88

# %%
def aux_CalculateTrajectoryError( trajectory, variablePoints ):
    
    totalError = 0.0
    
    for k in range( np.size( variablePoints ) ):
        
        if variablePoints[ k ]:
            single_point_error = aux_CalculateErrorSinglePoint( trajectory, k )
            
            if ~np.isnan(single_point_error):

                totalError += single_point_error
                
    
    return totalError




def aux_CalculateErrorSinglePoint( trajectory, targetPoint ):
    
    
    v_m1 = aux_haversine( trajectory[ targetPoint - 1, 2 ], trajectory[ targetPoint - 1, 1 ], trajectory[ targetPoint, 2 ], trajectory[ targetPoint, 1 ] )
    s_m1 = v_m1 / ( trajectory[ targetPoint, 0 ] - trajectory[ targetPoint - 1, 0 ] )
    
    
    v_m2 = aux_haversine( trajectory[ targetPoint - 2, 2 ], trajectory[ targetPoint - 2, 1 ], trajectory[ targetPoint - 1, 2 ], trajectory[ targetPoint - 1, 1 ] )
    s_m2 = v_m2 / ( trajectory[ targetPoint - 1, 0 ] - trajectory[ targetPoint - 2, 0 ] )
    
    
    v_p1 = aux_haversine( trajectory[ targetPoint, 2 ], trajectory[ targetPoint, 1 ], trajectory[ targetPoint + 1, 2 ], trajectory[ targetPoint + 1, 1 ] )
    s_p1 = v_p1 / ( trajectory[ targetPoint + 1, 0 ] - trajectory[ targetPoint, 0 ] )
    
    
    v_p2 = aux_haversine( trajectory[ targetPoint + 1, 2 ], trajectory[ targetPoint + 1, 1 ], trajectory[ targetPoint + 2, 2 ], trajectory[ targetPoint + 2, 1 ] )
    s_p2 = v_p2 / ( trajectory[ targetPoint + 2, 0 ] - trajectory[ targetPoint + 1, 0 ] )
    

    return np.std( [ v_m2, v_m1, v_p1, v_p2 ] ) / np.mean( [ v_m2, v_m1, v_p1, v_p2 ] )



def aux_haversine(lon1, lat1, lon2, lat2): # haversine is the angle distance between two points on a sphere 
    
    from math import radians, cos, sin, asin, sqrt

    R = 6372.8

    dLat = radians(lat2 - lat1)
    dLon = radians(lon2 - lon1)
    lat1 = radians(lat1)
    lat2 = radians(lat2)

    a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
    c = 2*asin(sqrt(a))

    return R * c

# %%
# @add_metaclass(ABCMeta)
# class ObjectiveFunction(object):

#     def __init__(self, name, dim, minf, maxf):
#         self.name = name
#         self.dim = dim
#         self.minf = minf
#         self.maxf = maxf

#     def sample(self):
#         return np.random.uniform(low=self.minf, high=self.maxf, size=self.dim)

#     def custom_sample(self):
#         return np.repeat(self.minf, repeats=self.dim) \
#                + np.random.uniform(low=0, high=1, size=self.dim) *\
#                np.repeat(self.maxf - self.minf, repeats=self.dim)

#     @abstractmethod
#     def evaluate(self, x):
#         pass


# class Sphere(ObjectiveFunction):

#     def __init__(self, dim):
#         super(Sphere, self).__init__('Sphere', dim, -100.0, 100.0)

#     def evaluate(self, x):
#         return sum(np.power(x, 2))


# class Rosenbrock(ObjectiveFunction):

#     def __init__(self, dim):
#         super(Rosenbrock, self).__init__('Rosenbrock', dim, -30.0, 30.0)

#     def evaluate(self, x):
#         return optimize.rosen(x)


# class Rastrigin(ObjectiveFunction):

#     def __init__(self, dim):
#         super(Rastrigin, self).__init__('Rastrigin', dim, -5.12, 5.12)

#     def evaluate(self, x):
#         return 10 * len(x)\
#                + np.sum(np.power(x, 2) - 10 * np.cos(2 * np.pi * np.array(x)))


# class Schwefel(ObjectiveFunction):

#     def __init__(self, dim):
#         super(Schwefel, self).__init__('Schwefel', dim, -500.0, 500.0)

#     def evaluate(self, x):
#         return schwefel(x)[0]

# %% [markdown]
# # Artificial bee colony

# %%
@add_metaclass(ABCMeta)
class ArtificialBee:
    
    TRIAL_INITIAL_DEFAULT_VALUE = 0
    INITIAL_DEFAULT_PROBABILITY = 0.0
    
    def __init__(self, trajectory, variablePoints, k, loss_function):
        
        self.trajectory = np.copy( trajectory )
        self.variablePoints = variablePoints
        self.k = k
        self.pos = self.trajectory[self.k]
        self.pos[1] += np.random.normal(0, .0005)
        self.pos[2] += np.random.normal(0, .0005)
        
        self.loss_function = loss_function

        self.fitness = loss_function(self.trajectory, self.variablePoints)
        self.trial = ArtificialBee.TRIAL_INITIAL_DEFAULT_VALUE
        self.prob = ArtificialBee.INITIAL_DEFAULT_PROBABILITY
        
    
    def update_bee(self, pos, fitness):
        
        if fitness <= self.fitness:
            
            self.pos = pos
            self.trajectory[self.k] = self.pos
            self.fitness = fitness
            self.trial = 0
            
        else:
            self.trial += 1
            
    def reset_bee(self, max_trials):
        
        if self.trial >= max_trials:
            
            self.__reset_bee()
            
    def __reset_bee(self):
        
        self.pos = self.trajectory[k]
        self.pos[1] += np.random.normal(0, .0005)
        self.pos[2] += np.random.normal(0, .0005)
        self.fitness = self.loss_function(self.trajectory, self.variablePoints)
        self.trial = ArtificialBee.TRIAL_INITIAL_DEFAULT_VALUE
        self.prob = ArtificialBee.INITIAL_DEFAULT_PROBABILITY

# %%
class EmployeeBee(ArtificialBee):
    
    def explore(self, max_trials):
        
        if self.trial <= max_trials:
            
            component = np.copy(self.pos)
            component[1] += np.random.normal(0, .001)
            component[2] += np.random.normal(0, .001)
            phi = np.random.uniform(low=-1, high=1, size=len(self.pos))
            n_pos = self.pos + (self.pos - component) * phi
            tmp = np.copy(self.trajectory)
            tmp[self.k] = n_pos
            n_fitness = self.loss_function(tmp, self.variablePoints)
            self.update_bee(n_pos, n_fitness)
            
    def get_fitness(self):
        return 1 / (1 + self.fitness) if self.fitness >= 0 else 1 + np.abs(self.fitness)
    
    def compute_prob(self, max_fitness):
        self.prob = self.get_fitness / max_fitness

# %%
class OnlookerBee(ArtificialBee):
    
    def onlook(self, best_food_sources, max_trials):
        candidate = np.random.choice(best_food_sources)
        self.__exploit(candidate.pos, candidate.fitness, max_trials)
    
    
    def __exploit(self, candidate, fitness, max_trials):
        
        if self.trial <= max_trials:
            
            component = np.random.choice(candidate)
            phi = np.random.uniform(low=-1, high=1, size=len(component))
            n_pos = candidate + (candidate - component) * phi
#             n_pos = self.evaluate_boundries(n_pos)
            tmp = np.copy(self.trajectory)
            tmp[self.k] = n_pos
            n_fitness = self.loss_function(tmp, self.variablePoints)
            
            if n_fitness <= fitness:
                
                self.pos = n_pos
                self.trajectory[self.k] = self.pos
                self.fitness = n_fitness
                self.trial = 0
                
            else:
                
                self.trial += 1

# %%
class ABC:
    
    def __init__(self, trajectory, variablePoints, loss_function, colony_size, n_iter, max_trials):
        
        self.trajectory = np.copy(trajectory)
        self.variablePoints = variablePoints
        self.colony_size = colony_size
        self.loss_function = loss_function
        self.n_iter = n_iter
        self.max_trials = max_trials
        
        self.optimal_solution = dict()
        self.optimality_tracking = dict()
        
        for k in np.where(self.variablePoints)[0]:
            self.optimal_solution[k] = None
            
            self.optimality_tracking[k] = np.copy(self.trajectory[k])
        
        
        self.employee_bees = dict()
        self.onlooker_bees = dict()
        
    
    def __reset_algorithm(self):
        self.optimal_solution = dict()
        self.optimality_tracking = dict()
        
        for k in np.where(self.variablePoints)[0]:
            self.optimal_solution[k] = None
            
            self.optimality_tracking[k] = np.copy(self.trajectory[k])
        
        
        
    def __update_optimality_tracking(self, k):

        Error = aux_CalculateTrajectoryError(self.trajectory, self.variablePoints)
        tmp = np.copy(self.trajectory)
        tmp[k] = self.optimal_solution[k].pos
        error = aux_CalculateTrajectoryError(tmp, self.variablePoints)
        
        if error < Error:
            
            print(f'For point {k} in trajectory.')
            print(f'Old error: {Error}')
            print(f'New error: {error}')
            print()
            
            self.trajectory = np.copy(tmp)
            
            self.optimality_tracking[k] = np.copy( self.optimal_solution[k].pos )
        
        
    def __update_optimal_solution(self, k):
        n_optimal_solution = min(self.onlooker_bees[k] + self.employee_bees[k], key=lambda bee: bee.fitness)
        
        if not self.optimal_solution[k]:
            
            self.optimal_solution[k] = deepcopy(n_optimal_solution)
        
        else:
            
            if n_optimal_solution.fitness < self.optimal_solution[k].fitness:
                
                print(f'New optimal solution for {k}: {n_optimal_solution.pos}')
                              
                self.optimal_solution[k] = deepcopy(n_optimal_solution)
    
    
    
    def __initialize_employees(self, k):

        self.employee_bees[k] = []
        
        for _ in range(self.colony_size // 2):
            self.employee_bees[k].append(EmployeeBee(self.trajectory, self.variablePoints, k, self.loss_function))
            
    def __initialize_onlookers(self, k):

        self.onlooker_bees[k] = []
        
        for _ in range(self.colony_size // 2):
            self.onlooker_bees[k].append(OnlookerBee(self.trajectory, self.variablePoints, k, self.loss_function))
            
    def __employee_bees_phase(self, k):
        map(lambda bee: bee.explore(self.max_trials), self.employee_bees[k])
        
    def __calculate_probabilities(self, k):
        
        sum_fitness = sum(map(lambda bee: bee.get_fitness(), self.employee_bees[k]))
        
        map(lambda bee: bee.compute_prob(sum_fitness), self.employee_bees[k])
        
    
    def __select_best_food_sources(self, k):
        
        self.best_food_sources = filter(lambda bee: bee.prob > np.random.uniform(low=0, high=1), self.employee_bees[k])
        
        while not self.best_food_sources:
            
            self.best_food_sources = filter(lambda bee: bee.prob > np.random.uniform(low=0, high=1), self.employee_bees[k])
            
    def __onlooker_bees_phase(self, k):
        map(lambda bee: bee.onlook(self.best_food_sources, self.max_trials), self.onlooker_bees[k])
        
    def __scout_bees_phase(self, k):
        map(lambda bee: bee.reset_bee(self.max_trials), self.onlooker_bees[k] + self.employee_bees[k])
        
    def optimize(self):
        
        self.__reset_algorithm()
        
        for k in np.where(self.variablePoints)[0]:

            self.__initialize_employees(k)
            self.__initialize_onlookers(k)
        
        
        for i in range(self.n_iter):
            
            for k in np.where(self.variablePoints)[0]:
            
                self.__employee_bees_phase(k)
                self.__update_optimal_solution(k)

                self.__calculate_probabilities(k)
                self.__select_best_food_sources(k)

                self.__onlooker_bees_phase(k)
                self.__scout_bees_phase(k)

                self.__update_optimal_solution(k)
                self.__update_optimality_tracking(k)

# %%
def simulate(trajectory, variablePoints, loss_function, colony_size=300, n_iter=1000, max_trials=100, simulations=200):
    
    bestTraj = np.copy(trajectory)
    
    for s in range(simulations):
        
        print(f'Simulation: {s}')
        
        optimizer = ABC(bestTraj, variablePoints, loss_function, colony_size, n_iter, max_trials)
        
        optimizer.optimize()
        
        
        for k in np.where(variablePoints)[0]:
            bestTraj[k] = optimizer.optimality_tracking[k]
            

            
    return bestTraj

# %%
targetPoints = []

targetPoints.append(np.array(range(299, 302)))

targetPoints = np.hstack(targetPoints)

# %%
variablePoints = np.zeros( ( np.size( trajectory1, 0 ) ), dtype = bool )

# %%
for i in range(len(variablePoints)):
    if i in targetPoints:
        variablePoints[i] = True

# %%
start_time = time.time()

correctedTraj1 = simulate(trajectory1, variablePoints, aux_CalculateTrajectoryError)

exec_time1 = time.time() - start_time
# Out:
# Simulation: 0
# For point 299 in trajectory.
# Old error: 2.467576363506674
# New error: 2.4581287487797594
#
# For point 300 in trajectory.
# Old error: 2.4581287487797594
# New error: 2.4574389759337087
#
# For point 301 in trajectory.
# Old error: 2.4574389759337087
# New error: 2.442911361894864
#
# Simulation: 1
# For point 299 in trajectory.
# Old error: 2.442911361894864
# New error: 2.4353817426206437
#
# For point 300 in trajectory.
# Old error: 2.4353817426206437
# New error: 2.4345818153498406
#
# For point 301 in trajectory.
# Old error: 2.4345818153498406
# New error: 2.4223287450846276
#
# Simulation: 2
# For point 299 in trajectory.
# Old error: 2.4223287450846276
# New error: 2.411765842743105
#
# For point 300 in trajectory.
# Old error: 2.411765842743105
# New error: 2.411232330827058
#
# For point 301 in trajectory.
# Old error: 2.411232330827058
# New error: 2.3993002986565797
#
# Simulation: 3
# For point 299 in trajectory.
# Old error: 2.3993002986565797
# New error: 2.3909734783309258
#
# For point 300 in trajectory.
# Old error: 2.3909734783309258
# New error: 2.39050294755605
#
# For point 301 in trajectory.
# Old error: 2.39050294755605
# New error: 2.38039411091552
#
# Simulation: 4
# For point 299 in trajectory.
# Old error: 2.38039411091552
# New error: 2.3724427486343616
#
# For point 300 in trajectory.
# Old error: 2.3724427486343616
# New error: 2.372141995235661
#
# For point 301 in trajectory.
# Old error: 2.372141995235661
# New error: 2.3597923137215666
#
# Simulation: 5
# For point 299 in trajectory.
# Old error: 2.3597923137215666
# New error: 2.3535673233246244
#
# For point 300 in trajectory.
# Old error: 2.3535673233246244
# New error: 2.3533152514543856
#
# For point 301 in trajectory.
# Old error: 2.3533152514543856
# New error: 2.3438946162882273
#
# Simulation: 6
# For point 299 in trajectory.
# Old error: 2.3438946162882273
# New error: 2.334988073741841
#
# For point 300 in trajectory.
# Old error: 2.334988073741841
# New error: 2.334691198469757
#
# For point 301 in trajectory.
# Old error: 2.334691198469757
# New error: 2.325137169993286
#
# Simulation: 7
# For point 299 in trajectory.
# Old error: 2.325137169993286
# New error: 2.3182051721043777
#
# For point 300 in trajectory.
# Old error: 2.3182051721043777
# New error: 2.3180728283693037
#
# For point 301 in trajectory.
# Old error: 2.3180728283693037
# New error: 2.307651459581455
#
# Simulation: 8
# For point 299 in trajectory.
# Old error: 2.307651459581455
# New error: 2.3001330441713894
#
# For point 300 in trajectory.
# Old error: 2.3001330441713894
# New error: 2.3000345465924363
#
# For point 301 in trajectory.
# Old error: 2.3000345465924363
# New error: 2.289474351305575
#
# Simulation: 9
# For point 299 in trajectory.
# Old error: 2.289474351305575
# New error: 2.281890946250731
#
# For point 300 in trajectory.
# Old error: 2.281890946250731
# New error: 2.2818616098168185
#
# For point 301 in trajectory.
# Old error: 2.2818616098168185
# New error: 2.268626219833852
#
# Simulation: 10
# For point 299 in trajectory.
# Old error: 2.268626219833852
# New error: 2.2594628450471346
#
# For point 300 in trajectory.
# Old error: 2.2594628450471346
# New error: 2.259410030492372
#
# For point 301 in trajectory.
# Old error: 2.259410030492372
# New error: 2.249878181897711
#
# Simulation: 11
# For point 299 in trajectory.
# Old error: 2.249878181897711
# New error: 2.2418091882609925
#
# For point 300 in trajectory.
# Old error: 2.2418091882609925
# New error: 2.2416892319843185
#
# For point 301 in trajectory.
# Old error: 2.2416892319843185
# New error: 2.231453830821856
#
# Simulation: 12
# For point 299 in trajectory.
# Old error: 2.231453830821856
# New error: 2.2253903378301816
#
# For point 300 in trajectory.
# Old error: 2.2253903378301816
# New error: 2.225222065185589
#
# For point 301 in trajectory.
# Old error: 2.225222065185589
# New error: 2.216748825571018
#
# Simulation: 13
# For point 299 in trajectory.
# Old error: 2.216748825571018
# New error: 2.208797898215269
#
# For point 300 in trajectory.
# Old error: 2.208797898215269
# New error: 2.208620699033572
#
# For point 301 in trajectory.
# Old error: 2.208620699033572
# New error: 2.201700514337199
#
# Simulation: 14
# For point 299 in trajectory.
# Old error: 2.201700514337199
# New error: 2.194936131233948
#
# For point 300 in trajectory.
# Old error: 2.194936131233948
# New error: 2.194667614624658
#
# For point 301 in trajectory.
# Old error: 2.194667614624658
# New error: 2.185674574757572
#
# Simulation: 15
# For point 299 in trajectory.
# Old error: 2.185674574757572
# New error: 2.1782555578587295
#
# For point 300 in trajectory.
# Old error: 2.1782555578587295
# New error: 2.177842718542781
#
# For point 301 in trajectory.
# Old error: 2.177842718542781
# New error: 2.169714126462145
#
# Simulation: 16
# For point 299 in trajectory.
# Old error: 2.169714126462145
# New error: 2.16187881750812
#
# For point 300 in trajectory.
# Old error: 2.16187881750812
# New error: 2.1614184280637243
#
# For point 301 in trajectory.
# Old error: 2.1614184280637243
# New error: 2.1525868457614363
#
# Simulation: 17
# For point 299 in trajectory.
# Old error: 2.1525868457614363
# New error: 2.145521619763979
#
# For point 300 in trajectory.
# Old error: 2.145521619763979
# New error: 2.1451128394447845
#
# For point 301 in trajectory.
# Old error: 2.1451128394447845
# New error: 2.134099820172396
#
# Simulation: 18
# For point 299 in trajectory.
# Old error: 2.134099820172396
# New error: 2.1274306878361324
#
# For point 300 in trajectory.
# Old error: 2.1274306878361324
# New error: 2.1269993684006456
#
# For point 301 in trajectory.
# Old error: 2.1269993684006456
# New error: 2.1184141687820683
#
# Simulation: 19
# For point 299 in trajectory.
# Old error: 2.1184141687820683
# New error: 2.1098254202230353
#
# For point 300 in trajectory.
# Old error: 2.1098254202230353
# New error: 2.1092587533273583
#
# For point 301 in trajectory.
# Old error: 2.1092587533273583
# New error: 2.1017979438543266
#
# Simulation: 20
# For point 299 in trajectory.
# Old error: 2.1017979438543266
# New error: 2.09483810512348
#
# For point 300 in trajectory.
# Old error: 2.09483810512348
# New error: 2.094314946550255
#
# For point 301 in trajectory.
# Old error: 2.094314946550255
# New error: 2.0826393121122635
#
# Simulation: 21
# For point 299 in trajectory.
# Old error: 2.0826393121122635
# New error: 2.0766544473297075
#
# For point 300 in trajectory.
# Old error: 2.0766544473297075
# New error: 2.075905862446269
#
# For point 301 in trajectory.
# Old error: 2.075905862446269
# New error: 2.06602980360595
#
# Simulation: 22
# For point 299 in trajectory.
# Old error: 2.06602980360595
# New error: 2.0603038258704265
#
# For point 300 in trajectory.
# Old error: 2.0603038258704265
# New error: 2.0595842033202443
#
# For point 301 in trajectory.
# Old error: 2.0595842033202443
# New error: 2.0503671365062743
#
# Simulation: 23
# For point 299 in trajectory.
# Old error: 2.0503671365062743
# New error: 2.044198852983479
#
# For point 300 in trajectory.
# Old error: 2.044198852983479
# New error: 2.043491494760384
#
# For point 301 in trajectory.
# Old error: 2.043491494760384
# New error: 2.0357442797089584
#
# Simulation: 24
# For point 299 in trajectory.
# Old error: 2.0357442797089584
# New error: 2.0288695736164337
#
# For point 300 in trajectory.
# Old error: 2.0288695736164337
# New error: 2.027916407328024
#
# For point 301 in trajectory.
# Old error: 2.027916407328024
# New error: 2.0166285378673416
#
# Simulation: 25
# For point 299 in trajectory.
# Old error: 2.0166285378673416
# New error: 2.0095924777897474
#
# For point 300 in trajectory.
# Old error: 2.0095924777897474
# New error: 2.0086696945447504
#
# For point 301 in trajectory.
# Old error: 2.0086696945447504
# New error: 1.9999206894778556
#
# Simulation: 26
# For point 299 in trajectory.
# Old error: 1.9999206894778556
# New error: 1.99442502675895
#
# For point 300 in trajectory.
# Old error: 1.99442502675895
# New error: 1.9934195381093132
#
# For point 301 in trajectory.
# Old error: 1.9934195381093132
# New error: 1.983833674402541
#
# Simulation: 27
# For point 299 in trajectory.
# Old error: 1.983833674402541
# New error: 1.9765487300696682
#
# For point 300 in trajectory.
# Old error: 1.9765487300696682
# New error: 1.9758762741021347
#
# For point 301 in trajectory.
# Old error: 1.9758762741021347
# New error: 1.9668443610119564
#
# Simulation: 28
# For point 299 in trajectory.
# Old error: 1.9668443610119564
# New error: 1.959735926990094
#
# For point 300 in trajectory.
# Old error: 1.959735926990094
# New error: 1.9587949982842046
#
# For point 301 in trajectory.
# Old error: 1.9587949982842046
# New error: 1.9496567341173603
#
# Simulation: 29
# For point 299 in trajectory.
# Old error: 1.9496567341173603
# New error: 1.9433778630634146
#
# For point 300 in trajectory.
# Old error: 1.9433778630634146
# New error: 1.9423797725660763
#
# For point 301 in trajectory.
# Old error: 1.9423797725660763
# New error: 1.934485018367909
# Simulation: 30
# For point 299 in trajectory.
# Old error: 1.934485018367909
# New error: 1.928145584580418
#
# For point 300 in trajectory.
# Old error: 1.928145584580418
# New error: 1.9270114889394292
#
# For point 301 in trajectory.
# Old error: 1.9270114889394292
# New error: 1.9192404372908787
#
# Simulation: 31
# For point 299 in trajectory.
# Old error: 1.9192404372908787
# New error: 1.913622958165122
#
# For point 300 in trajectory.
# Old error: 1.913622958165122
# New error: 1.9123148527498184
#
# For point 301 in trajectory.
# Old error: 1.9123148527498184
# New error: 1.9031551779635785
#
# Simulation: 32
# For point 299 in trajectory.
# Old error: 1.9031551779635785
# New error: 1.8960631739830012
#
# For point 300 in trajectory.
# Old error: 1.8960631739830012
# New error: 1.8948505372435835
#
# For point 301 in trajectory.
# Old error: 1.8948505372435835
# New error: 1.8878291920244807
#
# Simulation: 33
# For point 299 in trajectory.
# Old error: 1.8878291920244807
# New error: 1.8816619733903472
#
# For point 300 in trajectory.
# Old error: 1.8816619733903472
# New error: 1.880289796329102
#
# For point 301 in trajectory.
# Old error: 1.880289796329102
# New error: 1.8727094148475811
#
# Simulation: 34
# For point 299 in trajectory.
# Old error: 1.8727094148475811
# New error: 1.8677999464603343
#
# For point 300 in trajectory.
# Old error: 1.8677999464603343
# New error: 1.8667443643099668
#
# For point 301 in trajectory.
# Old error: 1.8667443643099668
# New error: 1.8595396704796205
#
# Simulation: 35
# For point 299 in trajectory.
# Old error: 1.8595396704796205
# New error: 1.853130383434085
#
# For point 300 in trajectory.
# Old error: 1.853130383434085
# New error: 1.8516208065745672
#
# For point 301 in trajectory.
# Old error: 1.8516208065745672
# New error: 1.8451074692923484
#
# Simulation: 36
# For point 299 in trajectory.
# Old error: 1.8451074692923484
# New error: 1.8389397416797337
#
# For point 300 in trajectory.
# Old error: 1.8389397416797337
# New error: 1.8377688064958329
#
# For point 301 in trajectory.
# Old error: 1.8377688064958329
# New error: 1.8298691876252704
#
# Simulation: 37
# For point 299 in trajectory.
# Old error: 1.8298691876252704
# New error: 1.8234307110192027
#
# For point 300 in trajectory.
# Old error: 1.8234307110192027
# New error: 1.8221780197810942
#
# For point 301 in trajectory.
# Old error: 1.8221780197810942
# New error: 1.8139809931462543
#
# Simulation: 38
# For point 299 in trajectory.
# Old error: 1.8139809931462543
# New error: 1.8079420017963954
#
# For point 300 in trajectory.
# Old error: 1.8079420017963954
# New error: 1.806558552763281
#
# For point 301 in trajectory.
# Old error: 1.806558552763281
# New error: 1.7977491980761593
#
# Simulation: 39
# For point 299 in trajectory.
# Old error: 1.7977491980761593
# New error: 1.7912470365011186
#
# For point 300 in trajectory.
# Old error: 1.7912470365011186
# New error: 1.789888431252296
#
# For point 301 in trajectory.
# Old error: 1.789888431252296
# New error: 1.7830820896332213
#
# Simulation: 40
# For point 299 in trajectory.
# Old error: 1.7830820896332213
# New error: 1.7766618470888216
#
# For point 300 in trajectory.
# Old error: 1.7766618470888216
# New error: 1.7751972140388144
#
# For point 301 in trajectory.
# Old error: 1.7751972140388144
# New error: 1.7689128177992626
#
# Simulation: 41
# For point 299 in trajectory.
# Old error: 1.7689128177992626
# New error: 1.7629793054437426
#
# For point 300 in trajectory.
# Old error: 1.7629793054437426
# New error: 1.761461385508216
#
# For point 301 in trajectory.
# Old error: 1.761461385508216
# New error: 1.755244760626093
#
# Simulation: 42
# For point 299 in trajectory.
# Old error: 1.755244760626093
# New error: 1.7497992423783548
#
# For point 300 in trajectory.
# Old error: 1.7497992423783548
# New error: 1.7484818896306842
#
# For point 301 in trajectory.
# Old error: 1.7484818896306842
# New error: 1.7395656441885379
#
# Simulation: 43
# For point 299 in trajectory.
# Old error: 1.7395656441885379
# New error: 1.7331047891141624
#
# For point 300 in trajectory.
# Old error: 1.7331047891141624
# New error: 1.7316439089074587
#
# For point 301 in trajectory.
# Old error: 1.7316439089074587
# New error: 1.72397000479166
#
# Simulation: 44
# For point 299 in trajectory.
# Old error: 1.72397000479166
# New error: 1.718429969441901
#
# For point 300 in trajectory.
# Old error: 1.718429969441901
# New error: 1.716898935808493
#
# For point 301 in trajectory.
# Old error: 1.716898935808493
# New error: 1.710520353850185
#
# Simulation: 45
# For point 299 in trajectory.
# Old error: 1.710520353850185
# New error: 1.7051190709544612
#
# For point 300 in trajectory.
# Old error: 1.7051190709544612
# New error: 1.7036727326604835
#
# For point 301 in trajectory.
# Old error: 1.7036727326604835
# New error: 1.6943592667679273
#
# Simulation: 46
# For point 299 in trajectory.
# Old error: 1.6943592667679273
# New error: 1.688831891929914
#
# For point 300 in trajectory.
# Old error: 1.688831891929914
# New error: 1.687303349520534
#
# For point 301 in trajectory.
# Old error: 1.687303349520534
# New error: 1.678756734774251
#
# Simulation: 47
# For point 299 in trajectory.
# Old error: 1.678756734774251
# New error: 1.6739820458092813
#
# For point 300 in trajectory.
# Old error: 1.6739820458092813
# New error: 1.6721529754072089
#
# For point 301 in trajectory.
# Old error: 1.6721529754072089
# New error: 1.6650387502440447
#
# Simulation: 48
# For point 299 in trajectory.
# Old error: 1.6650387502440447
# New error: 1.6605679077264044
#
# For point 300 in trajectory.
# Old error: 1.6605679077264044
# New error: 1.658493054472572
#
# For point 301 in trajectory.
# Old error: 1.658493054472572
# New error: 1.6515721083086143
#
# Simulation: 49
# For point 299 in trajectory.
# Old error: 1.6515721083086143
# New error: 1.6464172160851764
#
# For point 300 in trajectory.
# Old error: 1.6464172160851764
# New error: 1.644273478802626
#
# For point 301 in trajectory.
# Old error: 1.644273478802626
# New error: 1.6386892132377504
#
# Simulation: 50
# For point 299 in trajectory.
# Old error: 1.6386892132377504
# New error: 1.6332602360570645
#
# For point 300 in trajectory.
# Old error: 1.6332602360570645
# New error: 1.6317607744649663
#
# For point 301 in trajectory.
# Old error: 1.6317607744649663
# New error: 1.624623741633295
#
# Simulation: 51
# For point 299 in trajectory.
# Old error: 1.624623741633295
# New error: 1.6186315679540282
#
# For point 300 in trajectory.
# Old error: 1.6186315679540282
# New error: 1.6169916835647005
#
# For point 301 in trajectory.
# Old error: 1.6169916835647005
# New error: 1.6103818706080548
#
# Simulation: 52
# For point 299 in trajectory.
# Old error: 1.6103818706080548
# New error: 1.6042633880099384
#
# For point 300 in trajectory.
# Old error: 1.6042633880099384
# New error: 1.6026818783482162
#
# For point 301 in trajectory.
# Old error: 1.6026818783482162
# New error: 1.596981592491584
#
# Simulation: 53
# For point 299 in trajectory.
# Old error: 1.596981592491584
# New error: 1.591425594845759
#
# For point 300 in trajectory.
# Old error: 1.591425594845759
# New error: 1.5897156902176264
#
# For point 301 in trajectory.
# Old error: 1.5897156902176264
# New error: 1.5822538512534166
#
# Simulation: 54
# For point 299 in trajectory.
# Old error: 1.5822538512534166
# New error: 1.5756483455993973
#
# For point 300 in trajectory.
# Old error: 1.5756483455993973
# New error: 1.5741617759636293
#
# For point 301 in trajectory.
# Old error: 1.5741617759636293
# New error: 1.568526637580109
#
# Simulation: 55
# For point 299 in trajectory.
# Old error: 1.568526637580109
# New error: 1.5626136568347786
#
# For point 300 in trajectory.
# Old error: 1.5626136568347786
# New error: 1.560819456629636
#
# For point 301 in trajectory.
# Old error: 1.560819456629636
# New error: 1.5551802557407766
#
# Simulation: 56
# For point 299 in trajectory.
# Old error: 1.5551802557407766
# New error: 1.550344701835296
#
# For point 300 in trajectory.
# Old error: 1.550344701835296
# New error: 1.5485256684603632
#
# For point 301 in trajectory.
# Old error: 1.5485256684603632
# New error: 1.5411974634146395
#
# Simulation: 57
# For point 299 in trajectory.
# Old error: 1.5411974634146395
# New error: 1.5366532144240812
#
# For point 300 in trajectory.
# Old error: 1.5366532144240812
# New error: 1.5348784022789776
#
# For point 301 in trajectory.
# Old error: 1.5348784022789776
# New error: 1.5285247592187345
#
# Simulation: 58
# For point 299 in trajectory.
# Old error: 1.5285247592187345
# New error: 1.5228848145319789
#
# For point 300 in trajectory.
# Old error: 1.5228848145319789
# New error: 1.520974357549769
#
# For point 301 in trajectory.
# Old error: 1.520974357549769
# New error: 1.5150374012327257
# Simulation: 59
# For point 299 in trajectory.
# Old error: 1.5150374012327257
# New error: 1.5101910465105304
#
# For point 300 in trajectory.
# Old error: 1.5101910465105304
# New error: 1.50856856200229
#
# For point 301 in trajectory.
# Old error: 1.50856856200229
# New error: 1.502889400913592
#
# Simulation: 60
# For point 299 in trajectory.
# Old error: 1.502889400913592
# New error: 1.497826384972997
#
# For point 300 in trajectory.
# Old error: 1.497826384972997
# New error: 1.4964180895619648
#
# For point 301 in trajectory.
# Old error: 1.4964180895619648
# New error: 1.4905311799928693
#
# Simulation: 61
# For point 299 in trajectory.
# Old error: 1.4905311799928693
# New error: 1.4858847748020891
#
# For point 300 in trajectory.
# Old error: 1.4858847748020891
# New error: 1.4842439160770553
#
# For point 301 in trajectory.
# Old error: 1.4842439160770553
# New error: 1.4772415884043593
#
# Simulation: 62
# For point 299 in trajectory.
# Old error: 1.4772415884043593
# New error: 1.471600749366788
#
# For point 300 in trajectory.
# Old error: 1.471600749366788
# New error: 1.468717365032848
#
# For point 301 in trajectory.
# Old error: 1.468717365032848
# New error: 1.462969496255493
#
# Simulation: 63
# For point 299 in trajectory.
# Old error: 1.462969496255493
# New error: 1.4588506204455784
#
# For point 300 in trajectory.
# Old error: 1.4588506204455784
# New error: 1.4571829280189466
#
# For point 301 in trajectory.
# Old error: 1.4571829280189466
# New error: 1.4509828705478611
#
# Simulation: 64
# For point 299 in trajectory.
# Old error: 1.4509828705478611
# New error: 1.4474075178891501
#
# For point 300 in trajectory.
# Old error: 1.4474075178891501
# New error: 1.4454674630787823
#
# For point 301 in trajectory.
# Old error: 1.4454674630787823
# New error: 1.4386319194589214
#
# Simulation: 65
# For point 299 in trajectory.
# Old error: 1.4386319194589214
# New error: 1.4339101325953094
#
# For point 300 in trajectory.
# Old error: 1.4339101325953094
# New error: 1.4319848718129153
#
# For point 301 in trajectory.
# Old error: 1.4319848718129153
# New error: 1.425745140731192
#
# Simulation: 66
# For point 299 in trajectory.
# Old error: 1.425745140731192
# New error: 1.4216747957804556
#
# For point 300 in trajectory.
# Old error: 1.4216747957804556
# New error: 1.4194808081191348
#
# For point 301 in trajectory.
# Old error: 1.4194808081191348
# New error: 1.413325004598304
#
# Simulation: 67
# For point 299 in trajectory.
# Old error: 1.413325004598304
# New error: 1.4094170042525473
#
# For point 300 in trajectory.
# Old error: 1.4094170042525473
# New error: 1.407646263920165
#
# For point 301 in trajectory.
# Old error: 1.407646263920165
# New error: 1.4013565183944627
#
# Simulation: 68
# For point 299 in trajectory.
# Old error: 1.4013565183944627
# New error: 1.3964522074461545
#
# For point 300 in trajectory.
# Old error: 1.3964522074461545
# New error: 1.3943962324946653
#
# For point 301 in trajectory.
# Old error: 1.3943962324946653
# New error: 1.3874508839424582
#
# Simulation: 69
# For point 299 in trajectory.
# Old error: 1.3874508839424582
# New error: 1.3837119230502215
#
# For point 300 in trajectory.
# Old error: 1.3837119230502215
# New error: 1.3819768905956495
#
# For point 301 in trajectory.
# Old error: 1.3819768905956495
# New error: 1.3766477941312347
#
# Simulation: 70
# For point 299 in trajectory.
# Old error: 1.3766477941312347
# New error: 1.3725655818398517
#
# For point 300 in trajectory.
# Old error: 1.3725655818398517
# New error: 1.370609947293726
#
# For point 301 in trajectory.
# Old error: 1.370609947293726
# New error: 1.365392731830462
#
# Simulation: 71
# For point 299 in trajectory.
# Old error: 1.365392731830462
# New error: 1.361824200152152
#
# For point 300 in trajectory.
# Old error: 1.361824200152152
# New error: 1.3590585003657527
#
# For point 301 in trajectory.
# Old error: 1.3590585003657527
# New error: 1.3540834122619039
#
# Simulation: 72
# For point 299 in trajectory.
# Old error: 1.3540834122619039
# New error: 1.3494932772501067
#
# For point 300 in trajectory.
# Old error: 1.3494932772501067
# New error: 1.3478841303970701
#
# For point 301 in trajectory.
# Old error: 1.3478841303970701
# New error: 1.3428568535186303
#
# Simulation: 73
# For point 299 in trajectory.
# Old error: 1.3428568535186303
# New error: 1.3390268075889917
#
# For point 300 in trajectory.
# Old error: 1.3390268075889917
# New error: 1.336538371236582
#
# For point 301 in trajectory.
# Old error: 1.336538371236582
# New error: 1.3321138948650921
#
# Simulation: 74
# For point 299 in trajectory.
# Old error: 1.3321138948650921
# New error: 1.327646307507031
#
# For point 300 in trajectory.
# Old error: 1.327646307507031
# New error: 1.3257953042441755
#
# For point 301 in trajectory.
# Old error: 1.3257953042441755
# New error: 1.322049785576445
#
# Simulation: 75
# For point 299 in trajectory.
# Old error: 1.322049785576445
# New error: 1.318449045114851
#
# For point 300 in trajectory.
# Old error: 1.318449045114851
# New error: 1.3168867521765792
#
# For point 301 in trajectory.
# Old error: 1.3168867521765792
# New error: 1.312261607792043
#
# Simulation: 76
# For point 299 in trajectory.
# Old error: 1.312261607792043
# New error: 1.3081694699094126
#
# For point 300 in trajectory.
# Old error: 1.3081694699094126
# New error: 1.3061157664865415
#
# For point 301 in trajectory.
# Old error: 1.3061157664865415
# New error: 1.3013264232694248
#
# Simulation: 77
# For point 299 in trajectory.
# Old error: 1.3013264232694248
# New error: 1.2968537806034304
#
# For point 300 in trajectory.
# Old error: 1.2968537806034304
# New error: 1.295027179435718
#
# For point 301 in trajectory.
# Old error: 1.295027179435718
# New error: 1.2910644662493502
#
# Simulation: 78
# For point 299 in trajectory.
# Old error: 1.2910644662493502
# New error: 1.2867532033379814
#
# For point 300 in trajectory.
# Old error: 1.2867532033379814
# New error: 1.2851482938162584
#
# For point 301 in trajectory.
# Old error: 1.2851482938162584
# New error: 1.2802075099006633
#
# Simulation: 79
# For point 299 in trajectory.
# Old error: 1.2802075099006633
# New error: 1.2766876491449122
#
# For point 300 in trajectory.
# Old error: 1.2766876491449122
# New error: 1.274788267012606
#
# For point 301 in trajectory.
# Old error: 1.274788267012606
# New error: 1.2702862435031947
#
# Simulation: 80
# For point 299 in trajectory.
# Old error: 1.2702862435031947
# New error: 1.26660850430423
#
# For point 300 in trajectory.
# Old error: 1.26660850430423
# New error: 1.2645907230964466
#
# For point 301 in trajectory.
# Old error: 1.2645907230964466
# New error: 1.260571943587017
#
# Simulation: 81
# For point 299 in trajectory.
# Old error: 1.260571943587017
# New error: 1.2573762433473124
#
# For point 300 in trajectory.
# Old error: 1.2573762433473124
# New error: 1.2554426324074157
#
# For point 301 in trajectory.
# Old error: 1.2554426324074157
# New error: 1.2513688473537385
#
# Simulation: 82
# For point 299 in trajectory.
# Old error: 1.2513688473537385
# New error: 1.2476486664747637
#
# For point 300 in trajectory.
# Old error: 1.2476486664747637
# New error: 1.2460476874779451
#
# For point 301 in trajectory.
# Old error: 1.2460476874779451
# New error: 1.2412825210709584
#
# Simulation: 83
# For point 299 in trajectory.
# Old error: 1.2412825210709584
# New error: 1.2379476909522045
#
# For point 300 in trajectory.
# Old error: 1.2379476909522045
# New error: 1.2357127149122364
#
# For point 301 in trajectory.
# Old error: 1.2357127149122364
# New error: 1.2315127863931108
#
# Simulation: 84
# For point 299 in trajectory.
# Old error: 1.2315127863931108
# New error: 1.2279767655872011
#
# For point 300 in trajectory.
# Old error: 1.2279767655872011
# New error: 1.2260703599295681
#
# For point 301 in trajectory.
# Old error: 1.2260703599295681
# New error: 1.2214045758121648
#
# Simulation: 85
# For point 299 in trajectory.
# Old error: 1.2214045758121648
# New error: 1.2186227257125968
#
# For point 300 in trajectory.
# Old error: 1.2186227257125968
# New error: 1.216895347743682
#
# For point 301 in trajectory.
# Old error: 1.216895347743682
# New error: 1.2133224030479752
#
# Simulation: 86
# For point 299 in trajectory.
# Old error: 1.2133224030479752
# New error: 1.209668962061855
#
# For point 300 in trajectory.
# Old error: 1.209668962061855
# New error: 1.2077603724145387
#
# For point 301 in trajectory.
# Old error: 1.2077603724145387
# New error: 1.2040160442037398
#
# Simulation: 87
# For point 299 in trajectory.
# Old error: 1.2040160442037398
# New error: 1.2013440394899453
#
# For point 300 in trajectory.
# Old error: 1.2013440394899453
# New error: 1.1990092783048156
#
# For point 301 in trajectory.
# Old error: 1.1990092783048156
# New error: 1.1946951593995652
# Simulation: 88
# For point 299 in trajectory.
# Old error: 1.1946951593995652
# New error: 1.191014970068757
#
# For point 300 in trajectory.
# Old error: 1.191014970068757
# New error: 1.189071824704461
#
# For point 301 in trajectory.
# Old error: 1.189071824704461
# New error: 1.1848958834639451
#
# Simulation: 89
# For point 299 in trajectory.
# Old error: 1.1848958834639451
# New error: 1.182017287465295
#
# For point 300 in trajectory.
# Old error: 1.182017287465295
# New error: 1.1801979151139599
#
# For point 301 in trajectory.
# Old error: 1.1801979151139599
# New error: 1.1761321883678828
#
# Simulation: 90
# For point 299 in trajectory.
# Old error: 1.1761321883678828
# New error: 1.1732597553947768
#
# For point 300 in trajectory.
# Old error: 1.1732597553947768
# New error: 1.1717704242408442
#
# For point 301 in trajectory.
# Old error: 1.1717704242408442
# New error: 1.1679793832849097
#
# Simulation: 91
# For point 299 in trajectory.
# Old error: 1.1679793832849097
# New error: 1.1650722230126365
#
# For point 300 in trajectory.
# Old error: 1.1650722230126365
# New error: 1.1632967391258298
#
# For point 301 in trajectory.
# Old error: 1.1632967391258298
# New error: 1.1581351139486162
#
# Simulation: 92
# For point 299 in trajectory.
# Old error: 1.1581351139486162
# New error: 1.1553070416851756
#
# For point 300 in trajectory.
# Old error: 1.1553070416851756
# New error: 1.1535717697149648
#
# For point 301 in trajectory.
# Old error: 1.1535717697149648
# New error: 1.150783591884484
#
# Simulation: 93
# For point 299 in trajectory.
# Old error: 1.150783591884484
# New error: 1.1481690749965674
#
# For point 300 in trajectory.
# Old error: 1.1481690749965674
# New error: 1.1464364612557734
#
# For point 301 in trajectory.
# Old error: 1.1464364612557734
# New error: 1.142310888610159
#
# Simulation: 94
# For point 299 in trajectory.
# Old error: 1.142310888610159
# New error: 1.1395976305975684
#
# For point 300 in trajectory.
# Old error: 1.1395976305975684
# New error: 1.1377655838280996
#
# For point 301 in trajectory.
# Old error: 1.1377655838280996
# New error: 1.1342571522036158
#
# Simulation: 95
# For point 299 in trajectory.
# Old error: 1.1342571522036158
# New error: 1.1315746933459319
#
# For point 300 in trajectory.
# Old error: 1.1315746933459319
# New error: 1.1300845550310803
#
# For point 301 in trajectory.
# Old error: 1.1300845550310803
# New error: 1.1261000494979967
#
# Simulation: 96
# For point 299 in trajectory.
# Old error: 1.1261000494979967
# New error: 1.12349054455833
#
# For point 300 in trajectory.
# Old error: 1.12349054455833
# New error: 1.1217973722408188
#
# For point 301 in trajectory.
# Old error: 1.1217973722408188
# New error: 1.117773257878457
#
# Simulation: 97
# For point 299 in trajectory.
# Old error: 1.117773257878457
# New error: 1.1152394194214559
#
# For point 300 in trajectory.
# Old error: 1.1152394194214559
# New error: 1.1138333101538764
#
# For point 301 in trajectory.
# Old error: 1.1138333101538764
# New error: 1.11063355019009
#
# Simulation: 98
# For point 299 in trajectory.
# Old error: 1.11063355019009
# New error: 1.1066353204889752
#
# For point 300 in trajectory.
# Old error: 1.1066353204889752
# New error: 1.104795655971573
#
# For point 301 in trajectory.
# Old error: 1.104795655971573
# New error: 1.1015082284371858
#
# Simulation: 99
# For point 299 in trajectory.
# Old error: 1.1015082284371858
# New error: 1.0989510705410477
#
# For point 300 in trajectory.
# Old error: 1.0989510705410477
# New error: 1.0967140555723554
#
# For point 301 in trajectory.
# Old error: 1.0967140555723554
# New error: 1.0934613901654242
#
# Simulation: 100
# For point 299 in trajectory.
# Old error: 1.0934613901654242
# New error: 1.0910269149378062
#
# For point 300 in trajectory.
# Old error: 1.0910269149378062
# New error: 1.089391893799784
#
# For point 301 in trajectory.
# Old error: 1.089391893799784
# New error: 1.0861364437773324
#
# Simulation: 101
# For point 299 in trajectory.
# Old error: 1.0861364437773324
# New error: 1.083863607827845
#
# For point 300 in trajectory.
# Old error: 1.083863607827845
# New error: 1.0823520672660214
#
# For point 301 in trajectory.
# Old error: 1.0823520672660214
# New error: 1.0789399667362316
#
# Simulation: 102
# For point 299 in trajectory.
# Old error: 1.0789399667362316
# New error: 1.0766168684020632
#
# For point 300 in trajectory.
# Old error: 1.0766168684020632
# New error: 1.0752011552900238
#
# For point 301 in trajectory.
# Old error: 1.0752011552900238
# New error: 1.0725842589115142
#
# Simulation: 103
# For point 299 in trajectory.
# Old error: 1.0725842589115142
# New error: 1.0692636361708827
#
# For point 300 in trajectory.
# Old error: 1.0692636361708827
# New error: 1.0677699160532987
#
# For point 301 in trajectory.
# Old error: 1.0677699160532987
# New error: 1.0651281222808346
#
# Simulation: 104
# For point 299 in trajectory.
# Old error: 1.0651281222808346
# New error: 1.062600902843232
#
# For point 300 in trajectory.
# Old error: 1.062600902843232
# New error: 1.0613539187477379
#
# For point 301 in trajectory.
# Old error: 1.0613539187477379
# New error: 1.0578740310190673
#
# Simulation: 105
# For point 299 in trajectory.
# Old error: 1.0578740310190673
# New error: 1.0549045999952191
#
# For point 300 in trajectory.
# Old error: 1.0549045999952191
# New error: 1.0536813390423294
#
# For point 301 in trajectory.
# Old error: 1.0536813390423294
# New error: 1.0507032991333445
#
# Simulation: 106
# For point 299 in trajectory.
# Old error: 1.0507032991333445
# New error: 1.0477812087607845
#
# For point 300 in trajectory.
# Old error: 1.0477812087607845
# New error: 1.0465704482654072
#
# For point 301 in trajectory.
# Old error: 1.0465704482654072
# New error: 1.04370737301971
#
# Simulation: 107
# For point 299 in trajectory.
# Old error: 1.04370737301971
# New error: 1.0410716475494528
#
# For point 300 in trajectory.
# Old error: 1.0410716475494528
# New error: 1.0398689733518762
#
# For point 301 in trajectory.
# Old error: 1.0398689733518762
# New error: 1.0372873228166224
#
# Simulation: 108
# For point 299 in trajectory.
# Old error: 1.0372873228166224
# New error: 1.0353454500716568
#
# For point 300 in trajectory.
# Old error: 1.0353454500716568
# New error: 1.034079629850524
#
# For point 301 in trajectory.
# Old error: 1.034079629850524
# New error: 1.0315649885169007
#
# Simulation: 109
# For point 299 in trajectory.
# Old error: 1.0315649885169007
# New error: 1.02908785445144
#
# For point 300 in trajectory.
# Old error: 1.02908785445144
# New error: 1.027896251524668
#
# For point 301 in trajectory.
# Old error: 1.027896251524668
# New error: 1.0249319218385442
#
# Simulation: 110
# For point 299 in trajectory.
# Old error: 1.0249319218385442
# New error: 1.0227015286742862
#
# For point 300 in trajectory.
# Old error: 1.0227015286742862
# New error: 1.0216829932227793
#
# For point 301 in trajectory.
# Old error: 1.0216829932227793
# New error: 1.0188507420313653
#
# Simulation: 111
# For point 299 in trajectory.
# Old error: 1.0188507420313653
# New error: 1.0166946383182234
#
# For point 300 in trajectory.
# Old error: 1.0166946383182234
# New error: 1.0156474912686366
#
# For point 301 in trajectory.
# Old error: 1.0156474912686366
# New error: 1.0137547346047509
#
# Simulation: 112
# For point 299 in trajectory.
# Old error: 1.0137547346047509
# New error: 1.0115267980849272
#
# For point 300 in trajectory.
# Old error: 1.0115267980849272
# New error: 1.0102684356806022
#
# For point 301 in trajectory.
# Old error: 1.0102684356806022
# New error: 1.0077287007381788
#
# Simulation: 113
# For point 299 in trajectory.
# Old error: 1.0077287007381788
# New error: 1.0061370238012632
#
# For point 300 in trajectory.
# Old error: 1.0061370238012632
# New error: 1.0050157455176367
#
# For point 301 in trajectory.
# Old error: 1.0050157455176367
# New error: 1.0022340311597553
#
# Simulation: 114
# For point 299 in trajectory.
# Old error: 1.0022340311597553
# New error: 1.0002953704571829
#
# For point 300 in trajectory.
# Old error: 1.0002953704571829
# New error: 0.9992623959838434
#
# For point 301 in trajectory.
# Old error: 0.9992623959838434
# New error: 0.9965954413064887
#
# Simulation: 115
# For point 299 in trajectory.
# Old error: 0.9965954413064887
# New error: 0.9942517329486319
#
# For point 300 in trajectory.
# Old error: 0.9942517329486319
# New error: 0.9929641418698815
#
# For point 301 in trajectory.
# Old error: 0.9929641418698815
# New error: 0.9903727066270157
#
# Simulation: 116
# For point 299 in trajectory.
# Old error: 0.9903727066270157
# New error: 0.9883474505921572
#
# For point 300 in trajectory.
# Old error: 0.9883474505921572
# New error: 0.9872140161461089
#
# For point 301 in trajectory.
# Old error: 0.9872140161461089
# New error: 0.9850047704715086
#
# Simulation: 117
# For point 299 in trajectory.
# Old error: 0.9850047704715086
# New error: 0.9831340854457924
#
# For point 300 in trajectory.
# Old error: 0.9831340854457924
# New error: 0.9822190628459728
#
# For point 301 in trajectory.
# Old error: 0.9822190628459728
# New error: 0.9793916247706074
#
# Simulation: 118
# For point 299 in trajectory.
# Old error: 0.9793916247706074
# New error: 0.9771678561539997
#
# For point 300 in trajectory.
# Old error: 0.9771678561539997
# New error: 0.976216885804023
#
# For point 301 in trajectory.
# Old error: 0.976216885804023
# New error: 0.9730769495209906
#
# Simulation: 119
# For point 299 in trajectory.
# Old error: 0.9730769495209906
# New error: 0.9713816037804496
#
# For point 300 in trajectory.
# Old error: 0.9713816037804496
# New error: 0.9705699981052216
#
# For point 301 in trajectory.
# Old error: 0.9705699981052216
# New error: 0.9680174076535866
#
# Simulation: 120
# For point 299 in trajectory.
# Old error: 0.9680174076535866
# New error: 0.9663507769738751
#
# For point 300 in trajectory.
# Old error: 0.9663507769738751
# New error: 0.9655773150158462
#
# For point 301 in trajectory.
# Old error: 0.9655773150158462
# New error: 0.9629231180967937
#
# Simulation: 121
# For point 299 in trajectory.
# Old error: 0.9629231180967937
# New error: 0.9614662153764106
#
# For point 300 in trajectory.
# Old error: 0.9614662153764106
# New error: 0.9607269580166347
#
# For point 301 in trajectory.
# Old error: 0.9607269580166347
# New error: 0.9581453137207306
#
# Simulation: 122
# For point 299 in trajectory.
# Old error: 0.9581453137207306
# New error: 0.9564049183238215
#
# For point 300 in trajectory.
# Old error: 0.9564049183238215
# New error: 0.9556673436826416
#
# For point 301 in trajectory.
# Old error: 0.9556673436826416
# New error: 0.9531951261776519
#
# Simulation: 123
# For point 299 in trajectory.
# Old error: 0.9531951261776519
# New error: 0.95172107135021
#
# For point 300 in trajectory.
# Old error: 0.95172107135021
# New error: 0.9505630027761309
#
# For point 301 in trajectory.
# Old error: 0.9505630027761309
# New error: 0.9486755768559976
#
# Simulation: 124
# For point 299 in trajectory.
# Old error: 0.9486755768559976
# New error: 0.9473999464167563
#
# For point 300 in trajectory.
# Old error: 0.9473999464167563
# New error: 0.9465244626350335
#
# For point 301 in trajectory.
# Old error: 0.9465244626350335
# New error: 0.9442169076608022
#
# Simulation: 125
# For point 299 in trajectory.
# Old error: 0.9442169076608022
# New error: 0.9428043598682581
#
# For point 300 in trajectory.
# Old error: 0.9428043598682581
# New error: 0.9420697609560449
#
# For point 301 in trajectory.
# Old error: 0.9420697609560449
# New error: 0.9390659898660625
#
# Simulation: 126
# For point 299 in trajectory.
# Old error: 0.9390659898660625
# New error: 0.9376174486415676
#
# For point 300 in trajectory.
# Old error: 0.9376174486415676
# New error: 0.9367062557581222
#
# For point 301 in trajectory.
# Old error: 0.9367062557581222
# New error: 0.9346040144104854
#
# Simulation: 127
# For point 299 in trajectory.
# Old error: 0.9346040144104854
# New error: 0.9331202171676009
#
# For point 300 in trajectory.
# Old error: 0.9331202171676009
# New error: 0.9324405967553787
#
# For point 301 in trajectory.
# Old error: 0.9324405967553787
# New error: 0.9297284851620878
#
# Simulation: 128
# For point 299 in trajectory.
# Old error: 0.9297284851620878
# New error: 0.9281795186920921
#
# For point 300 in trajectory.
# Old error: 0.9281795186920921
# New error: 0.9275838615672154
#
# For point 301 in trajectory.
# Old error: 0.9275838615672154
# New error: 0.9255381480437099
#
# Simulation: 129
# For point 299 in trajectory.
# Old error: 0.9255381480437099
# New error: 0.9241090830988314
#
# For point 300 in trajectory.
# Old error: 0.9241090830988314
# New error: 0.9236251255125427
#
# For point 301 in trajectory.
# Old error: 0.9236251255125427
# New error: 0.9208572992368349
#
# Simulation: 130
# For point 299 in trajectory.
# Old error: 0.9208572992368349
# New error: 0.9195684018686487
#
# For point 300 in trajectory.
# Old error: 0.9195684018686487
# New error: 0.9191005470975011
#
# For point 301 in trajectory.
# Old error: 0.9191005470975011
# New error: 0.916802880207487
#
# Simulation: 131
# For point 299 in trajectory.
# Old error: 0.916802880207487
# New error: 0.9152807224885849
#
# For point 300 in trajectory.
# Old error: 0.9152807224885849
# New error: 0.9145787658219973
#
# For point 301 in trajectory.
# Old error: 0.9145787658219973
# New error: 0.9113049778942166
#
# Simulation: 132
# For point 299 in trajectory.
# Old error: 0.9113049778942166
# New error: 0.9101386787108143
#
# For point 300 in trajectory.
# Old error: 0.9101386787108143
# New error: 0.9095326098612846
#
# For point 301 in trajectory.
# Old error: 0.9095326098612846
# New error: 0.9077260761989937
#
# Simulation: 133
# For point 299 in trajectory.
# Old error: 0.9077260761989937
# New error: 0.9068173923893516
#
# For point 300 in trajectory.
# Old error: 0.9068173923893516
# New error: 0.9062950432017578
#
# For point 301 in trajectory.
# Old error: 0.9062950432017578
# New error: 0.903200787654269
#
# Simulation: 134
# For point 299 in trajectory.
# Old error: 0.903200787654269
# New error: 0.9022781413752812
#
# For point 300 in trajectory.
# Old error: 0.9022781413752812
# New error: 0.9018771532953522
#
# For point 301 in trajectory.
# Old error: 0.9018771532953522
# New error: 0.8991095692075559
#
# Simulation: 135
# For point 299 in trajectory.
# Old error: 0.8991095692075559
# New error: 0.8981170880228027
#
# For point 300 in trajectory.
# Old error: 0.8981170880228027
# New error: 0.8975841720240569
#
# For point 301 in trajectory.
# Old error: 0.8975841720240569
# New error: 0.8947085255200575
#
# Simulation: 136
# For point 299 in trajectory.
# Old error: 0.8947085255200575
# New error: 0.8938907124479986
#
# For point 300 in trajectory.
# Old error: 0.8938907124479986
# New error: 0.8933759196054037
#
# For point 301 in trajectory.
# Old error: 0.8933759196054037
# New error: 0.8910952080558749
#
# Simulation: 137
# For point 299 in trajectory.
# Old error: 0.8910952080558749
# New error: 0.8902565174171665
#
# For point 300 in trajectory.
# Old error: 0.8902565174171665
# New error: 0.8899478279047841
#
# For point 301 in trajectory.
# Old error: 0.8899478279047841
# New error: 0.887601958666482
#
# Simulation: 138
# For point 299 in trajectory.
# Old error: 0.887601958666482
# New error: 0.8868540887924374
#
# For point 300 in trajectory.
# Old error: 0.8868540887924374
# New error: 0.8864575497010807
#
# For point 301 in trajectory.
# Old error: 0.8864575497010807
# New error: 0.8843638943372566
#
# Simulation: 139
# For point 299 in trajectory.
# Old error: 0.8843638943372566
# New error: 0.8837388041444203
#
# For point 300 in trajectory.
# Old error: 0.8837388041444203
# New error: 0.8834284847828004
#
# For point 301 in trajectory.
# Old error: 0.8834284847828004
# New error: 0.8805946197281538
#
# Simulation: 140
# For point 299 in trajectory.
# Old error: 0.8805946197281538
# New error: 0.8797854161551222
#
# For point 300 in trajectory.
# Old error: 0.8797854161551222
# New error: 0.8795202896415029
#
# For point 301 in trajectory.
# Old error: 0.8795202896415029
# New error: 0.8770875495707018
#
# Simulation: 141
# For point 299 in trajectory.
# Old error: 0.8770875495707018
# New error: 0.8764822525937556
#
# For point 300 in trajectory.
# Old error: 0.8764822525937556
# New error: 0.8761694659629895
#
# For point 301 in trajectory.
# Old error: 0.8761694659629895
# New error: 0.8734802301598854
#
# Simulation: 142
# For point 299 in trajectory.
# Old error: 0.8734802301598854
# New error: 0.8731018446957052
#
# For point 300 in trajectory.
# Old error: 0.8731018446957052
# New error: 0.8728822521750266
#
# For point 301 in trajectory.
# Old error: 0.8728822521750266
# New error: 0.8700919982911517
#
# Simulation: 143
# For point 299 in trajectory.
# Old error: 0.8700919982911517
# New error: 0.86964337025549
#
# For point 300 in trajectory.
# Old error: 0.86964337025549
# New error: 0.8695048467416278
#
# For point 301 in trajectory.
# Old error: 0.8695048467416278
# New error: 0.8661260426079287
#
# Simulation: 144
# For point 299 in trajectory.
# Old error: 0.8661260426079287
# New error: 0.8658603682021829
#
# For point 300 in trajectory.
# Old error: 0.8658603682021829
# New error: 0.8656320949488153
#
# For point 301 in trajectory.
# Old error: 0.8656320949488153
# New error: 0.8630123612826277
#
# Simulation: 145
# For point 299 in trajectory.
# Old error: 0.8630123612826277
# New error: 0.8626802671830386
#
# For point 300 in trajectory.
# Old error: 0.8626802671830386
# New error: 0.8624655757902264
#
# For point 301 in trajectory.
# Old error: 0.8624655757902264
# New error: 0.8600074427114163
# Simulation: 146
# For point 299 in trajectory.
# Old error: 0.8600074427114163
# New error: 0.8595460390387192
#
# For point 300 in trajectory.
# Old error: 0.8595460390387192
# New error: 0.8594618343390381
#
# For point 301 in trajectory.
# Old error: 0.8594618343390381
# New error: 0.8561157601719529
#
# Simulation: 147
# For point 299 in trajectory.
# Old error: 0.8561157601719529
# New error: 0.8558503917731533
#
# For point 301 in trajectory.
# Old error: 0.8558503917731533
# New error: 0.8527523252125042
#
# For point 300 in trajectory.
# Old error: 0.8527523252125042
# New error: 0.8526716529693167
#
# Simulation: 148
# For point 299 in trajectory.
# Old error: 0.8526716529693167
# New error: 0.8525157887787344
#
# For point 300 in trajectory.
# Old error: 0.8525157887787344
# New error: 0.8524788045665044
#
# For point 301 in trajectory.
# Old error: 0.8524788045665044
# New error: 0.8495950554155072
#
# Simulation: 149
# For point 299 in trajectory.
# Old error: 0.8495950554155072
# New error: 0.8494144374304067
#
# For point 300 in trajectory.
# Old error: 0.8494144374304067
# New error: 0.8494033573947077
#
# For point 301 in trajectory.
# Old error: 0.8494033573947077
# New error: 0.8466794575159475
#
# Simulation: 150
# For point 299 in trajectory.
# Old error: 0.8466794575159475
# New error: 0.8465210988964371
#
# For point 301 in trajectory.
# Old error: 0.8465210988964371
# New error: 0.8440396998138439
#
# Simulation: 151
# For point 299 in trajectory.
# Old error: 0.8440396998138439
# New error: 0.8439673581146807
#
# For point 301 in trajectory.
# Old error: 0.8439673581146807
# New error: 0.8411730459389253
#
# For point 300 in trajectory.
# Old error: 0.8411730459389253
# New error: 0.8411728257288309
#
# Simulation: 152
# For point 299 in trajectory.
# Old error: 0.8411728257288309
# New error: 0.841117164900093
#
# For point 301 in trajectory.
# Old error: 0.841117164900093
# New error: 0.8377881853966651
#
# For point 300 in trajectory.
# Old error: 0.8377881853966651
# New error: 0.8377652660069153
#
# Simulation: 153
# For point 299 in trajectory.
# Old error: 0.8377652660069153
# New error: 0.8376181355618297
#
# For point 301 in trajectory.
# Old error: 0.8376181355618297
# New error: 0.8344755783882352
#
# For point 300 in trajectory.
# Old error: 0.8344755783882352
# New error: 0.8344179944286896
#
# Simulation: 154
# For point 299 in trajectory.
# Old error: 0.8344179944286896
# New error: 0.8343508119922406
#
# For point 301 in trajectory.
# Old error: 0.8343508119922406
# New error: 0.831721066465509
#
# For point 300 in trajectory.
# Old error: 0.831721066465509
# New error: 0.8317005053679531
#
# Simulation: 155
# For point 299 in trajectory.
# Old error: 0.8317005053679531
# New error: 0.8315890099385883
#
# For point 301 in trajectory.
# Old error: 0.8315890099385883
# New error: 0.8288392114204964
#
# For point 300 in trajectory.
# Old error: 0.8288392114204964
# New error: 0.8287963354399552
#
# Simulation: 156
# For point 299 in trajectory.
# Old error: 0.8287963354399552
# New error: 0.8287232556086029
#
# For point 301 in trajectory.
# Old error: 0.8287232556086029
# New error: 0.8262562066395538
#
# For point 300 in trajectory.
# Old error: 0.8262562066395538
# New error: 0.8262428815276197
#
# Simulation: 157
# For point 299 in trajectory.
# Old error: 0.8262428815276197
# New error: 0.826189515410497
#
# For point 301 in trajectory.
# Old error: 0.826189515410497
# New error: 0.8234489722084337
#
# For point 300 in trajectory.
# Old error: 0.8234489722084337
# New error: 0.8234327924926818
#
# Simulation: 158
# For point 299 in trajectory.
# Old error: 0.8234327924926818
# New error: 0.8233151256709728
#
# For point 301 in trajectory.
# Old error: 0.8233151256709728
# New error: 0.8208159122742582
#
# For point 300 in trajectory.
# Old error: 0.8208159122742582
# New error: 0.8207570706708124
#
# Simulation: 159
# For point 299 in trajectory.
# Old error: 0.8207570706708124
# New error: 0.8206360580576004
#
# For point 301 in trajectory.
# Old error: 0.8206360580576004
# New error: 0.8180737668408955
#
# For point 300 in trajectory.
# Old error: 0.8180737668408955
# New error: 0.8180308877995326
#
# Simulation: 160
# For point 299 in trajectory.
# Old error: 0.8180308877995326
# New error: 0.8179452284948217
#
# For point 301 in trajectory.
# Old error: 0.8179452284948217
# New error: 0.8149817970974331
#
# For point 300 in trajectory.
# Old error: 0.8149817970974331
# New error: 0.8149439954460818
#
# Simulation: 161
# For point 299 in trajectory.
# Old error: 0.8149439954460818
# New error: 0.8148425071103317
#
# For point 301 in trajectory.
# Old error: 0.8148425071103317
# New error: 0.8122935454894953
#
# For point 300 in trajectory.
# Old error: 0.8122935454894953
# New error: 0.8122677474031181
#
# Simulation: 162
# For point 299 in trajectory.
# Old error: 0.8122677474031181
# New error: 0.8121997157751235
#
# For point 301 in trajectory.
# Old error: 0.8121997157751235
# New error: 0.8095468802319932
#
# For point 300 in trajectory.
# Old error: 0.8095468802319932
# New error: 0.8095292295826
#
# Simulation: 163
# For point 299 in trajectory.
# Old error: 0.8095292295826
# New error: 0.8094779319597699
#
# For point 300 in trajectory.
# Old error: 0.8094779319597699
# New error: 0.8094740334330089
#
# For point 301 in trajectory.
# Old error: 0.8094740334330089
# New error: 0.8072600872551672
#
# Simulation: 164
# For point 299 in trajectory.
# Old error: 0.8072600872551672
# New error: 0.8071469273138885
#
# For point 301 in trajectory.
# Old error: 0.8071469273138885
# New error: 0.8049332311361845
#
# For point 300 in trajectory.
# Old error: 0.8049332311361845
# New error: 0.8049106049730861
#
# Simulation: 165
# For point 299 in trajectory.
# Old error: 0.8049106049730861
# New error: 0.804869117104499
#
# For point 300 in trajectory.
# Old error: 0.804869117104499
# New error: 0.80486501367356
#
# For point 301 in trajectory.
# Old error: 0.80486501367356
# New error: 0.8023190886442173
#
# Simulation: 166
# For point 299 in trajectory.
# Old error: 0.8023190886442173
# New error: 0.8021639482024228
#
# For point 301 in trajectory.
# Old error: 0.8021639482024228
# New error: 0.7994876361267498
#
# For point 300 in trajectory.
# Old error: 0.7994876361267498
# New error: 0.799415898173281
#
# Simulation: 167
# For point 299 in trajectory.
# Old error: 0.799415898173281
# New error: 0.7993341491648613
#
# For point 301 in trajectory.
# Old error: 0.7993341491648613
# New error: 0.7970768696980439
#
# For point 300 in trajectory.
# Old error: 0.7970768696980439
# New error: 0.7970684643119155
#
# Simulation: 168
# For point 299 in trajectory.
# Old error: 0.7970684643119155
# New error: 0.7970213562169282
#
# For point 300 in trajectory.
# Old error: 0.7970213562169282
# New error: 0.7970126340626202
#
# For point 301 in trajectory.
# Old error: 0.7970126340626202
# New error: 0.7946733286849907
#
# Simulation: 169
# For point 299 in trajectory.
# Old error: 0.7946733286849907
# New error: 0.7945530917737498
#
# For point 301 in trajectory.
# Old error: 0.7945530917737498
# New error: 0.792483863973552
#
# For point 300 in trajectory.
# Old error: 0.792483863973552
# New error: 0.7924691563175835
#
# Simulation: 170
# For point 299 in trajectory.
# Old error: 0.7924691563175835
# New error: 0.7924403772119364
#
# For point 300 in trajectory.
# Old error: 0.7924403772119364
# New error: 0.7924187245804343
#
# For point 301 in trajectory.
# Old error: 0.7924187245804343
# New error: 0.7899819505610156
#
# Simulation: 171
# For point 299 in trajectory.
# Old error: 0.7899819505610156
# New error: 0.7898360900626393
#
# For point 301 in trajectory.
# Old error: 0.7898360900626393
# New error: 0.7872505257084754
#
# For point 300 in trajectory.
# Old error: 0.7872505257084754
# New error: 0.7872007619480277
#
# Simulation: 172
# For point 299 in trajectory.
# Old error: 0.7872007619480277
# New error: 0.7871483967000266
#
# For point 301 in trajectory.
# Old error: 0.7871483967000266
# New error: 0.7846845693139797
#
# For point 300 in trajectory.
# Old error: 0.7846845693139797
# New error: 0.7846703314693049
#
# Simulation: 173
# For point 299 in trajectory.
# Old error: 0.7846703314693049
# New error: 0.7844874591386107
#
# For point 301 in trajectory.
# Old error: 0.7844874591386107
# New error: 0.7820632630726614
#
# For point 300 in trajectory.
# Old error: 0.7820632630726614
# New error: 0.7819845838869646
#
# Simulation: 174
# For point 299 in trajectory.
# Old error: 0.7819845838869646
# New error: 0.7819172114043886
#
# For point 301 in trajectory.
# Old error: 0.7819172114043886
# New error: 0.7798387054969487
#
# For point 300 in trajectory.
# Old error: 0.7798387054969487
# New error: 0.7798324506911086
#
# Simulation: 175
# For point 299 in trajectory.
# Old error: 0.7798324506911086
# New error: 0.779771677372006
#
# For point 301 in trajectory.
# Old error: 0.779771677372006
# New error: 0.7776386564232878
#
# For point 300 in trajectory.
# Old error: 0.7776386564232878
# New error: 0.7776147014354124
#
# Simulation: 176
# For point 299 in trajectory.
# Old error: 0.7776147014354124
# New error: 0.777552041824034
#
# For point 301 in trajectory.
# Old error: 0.777552041824034
# New error: 0.7746766635573559
#
# For point 300 in trajectory.
# Old error: 0.7746766635573559
# New error: 0.774644756733858
#
# Simulation: 177
# For point 299 in trajectory.
# Old error: 0.774644756733858
# New error: 0.7744458076495488
#
# For point 301 in trajectory.
# Old error: 0.7744458076495488
# New error: 0.7719352471385128
#
# For point 300 in trajectory.
# Old error: 0.7719352471385128
# New error: 0.7718600133743895
#
# Simulation: 178
# For point 299 in trajectory.
# Old error: 0.7718600133743895
# New error: 0.7718248913094361
#
# For point 300 in trajectory.
# Old error: 0.7718248913094361
# New error: 0.7718174423524158
#
# For point 301 in trajectory.
# Old error: 0.7718174423524158
# New error: 0.7695998943927884
#
# Simulation: 179
# For point 299 in trajectory.
# Old error: 0.7695998943927884
# New error: 0.7693755071325314
#
# For point 301 in trajectory.
# Old error: 0.7693755071325314
# New error: 0.7674414937492129
#
# For point 300 in trajectory.
# Old error: 0.7674414937492129
# New error: 0.7674152987144252
#
# Simulation: 180
# For point 299 in trajectory.
# Old error: 0.7674152987144252
# New error: 0.7673953913098754
#
# For point 300 in trajectory.
# Old error: 0.7673953913098754
# New error: 0.767370952920146
#
# For point 301 in trajectory.
# Old error: 0.767370952920146
# New error: 0.7654472463951941
#
# Simulation: 181
# For point 299 in trajectory.
# Old error: 0.7654472463951941
# New error: 0.7651440944242669
#
# For point 301 in trajectory.
# Old error: 0.7651440944242669
# New error: 0.7630421710128161
#
# For point 300 in trajectory.
# Old error: 0.7630421710128161
# New error: 0.7630015005797718
#
# Simulation: 182
# For point 299 in trajectory.
# Old error: 0.7630015005797718
# New error: 0.7629875647245025
#
# For point 300 in trajectory.
# Old error: 0.7629875647245025
# New error: 0.7629750416888019
#
# For point 301 in trajectory.
# Old error: 0.7629750416888019
# New error: 0.7609367256165759
#
# Simulation: 183
# For point 299 in trajectory.
# Old error: 0.7609367256165759
# New error: 0.760494031409799
#
# For point 301 in trajectory.
# Old error: 0.760494031409799
# New error: 0.7584175857793016
#
# For point 300 in trajectory.
# Old error: 0.7584175857793016
# New error: 0.7580000543077056
#
# Simulation: 184
# For point 299 in trajectory.
# Old error: 0.7580000543077056
# New error: 0.7579312656108558
#
# For point 301 in trajectory.
# Old error: 0.7579312656108558
# New error: 0.7559758298114492
#
# For point 300 in trajectory.
# Old error: 0.7559758298114492
# New error: 0.7559077179381134
#
# Simulation: 185
# For point 299 in trajectory.
# Old error: 0.7559077179381134
# New error: 0.7557616277074211
#
# For point 301 in trajectory.
# Old error: 0.7557616277074211
# New error: 0.7541894560556216
#
# For point 300 in trajectory.
# Old error: 0.7541894560556216
# New error: 0.7541246582657415
#
# Simulation: 186
# For point 299 in trajectory.
# Old error: 0.7541246582657415
# New error: 0.7541047727439534
#
# For point 300 in trajectory.
# Old error: 0.7541047727439534
# New error: 0.7540965600097943
#
# For point 301 in trajectory.
# Old error: 0.7540965600097943
# New error: 0.7522833207700724
#
# Simulation: 187
# For point 299 in trajectory.
# Old error: 0.7522833207700724
# New error: 0.751747032554634
#
# For point 301 in trajectory.
# Old error: 0.751747032554634
# New error: 0.7498208271551686
#
# For point 300 in trajectory.
# Old error: 0.7498208271551686
# New error: 0.7494344362288736
#
# Simulation: 188
# For point 299 in trajectory.
# Old error: 0.7494344362288736
# New error: 0.7493494773056848
#
# For point 301 in trajectory.
# Old error: 0.7493494773056848
# New error: 0.7474852280717246
#
# For point 300 in trajectory.
# Old error: 0.7474852280717246
# New error: 0.7474505090208077
#
# Simulation: 189
# For point 299 in trajectory.
# Old error: 0.7474505090208077
# New error: 0.7471535148674562
#
# For point 301 in trajectory.
# Old error: 0.7471535148674562
# New error: 0.7459187340902912
#
# Simulation: 190
# For point 299 in trajectory.
# Old error: 0.7459187340902912
# New error: 0.7458279984015204
#
# For point 301 in trajectory.
# Old error: 0.7458279984015204
# New error: 0.7446910426893916
#
# For point 300 in trajectory.
# Old error: 0.7446910426893916
# New error: 0.7446585987631755
#
# Simulation: 191
# For point 299 in trajectory.
# Old error: 0.7446585987631755
# New error: 0.7446386424195177
#
# For point 301 in trajectory.
# Old error: 0.7446386424195177
# New error: 0.7435888677790097
#
# Simulation: 192
# For point 299 in trajectory.
# Old error: 0.7435888677790097
# New error: 0.7433613468671166
#
# For point 301 in trajectory.
# Old error: 0.7433613468671166
# New error: 0.7427179247713857
#
# Simulation: 193
# For point 299 in trajectory.
# Old error: 0.7427179247713857
# New error: 0.7427057888265298
#
# For point 301 in trajectory.
# Old error: 0.7427057888265298
# New error: 0.7420806889776179
#
# For point 300 in trajectory.
# Old error: 0.7420806889776179
# New error: 0.7420565909917078
#
# Simulation: 194
# For point 299 in trajectory.
# Old error: 0.7420565909917078
# New error: 0.7420101171749548
#
# For point 301 in trajectory.
# Old error: 0.7420101171749548
# New error: 0.7416234012252729
#
# Simulation: 195
# For point 299 in trajectory.
# Old error: 0.7416234012252729
# New error: 0.7416228813912848
#
# For point 301 in trajectory.
# Old error: 0.7416228813912848
# New error: 0.7413520194465999
#
# Simulation: 196
# For point 299 in trajectory.
# Old error: 0.7413520194465999
# New error: 0.7412973658043092
#
# Simulation: 197
# For point 299 in trajectory.
# Old error: 0.7412973658043092
# New error: 0.741296304821617
#
# For point 301 in trajectory.
# Old error: 0.741296304821617
# New error: 0.7412903693986728
#
# For point 300 in trajectory.
# Old error: 0.7412903693986728
# New error: 0.741287456128391
#
# Simulation: 198
# For point 299 in trajectory.
# Old error: 0.741287456128391
# New error: 0.741223649084549
#
# Simulation: 199
# For point 300 in trajectory.
# Old error: 0.741223649084549
# New error: 0.7412210082113593
#
# For point 301 in trajectory.
# Old error: 0.7412210082113593
# New error: 0.7411546134172764

# %%
print(f'Execution time of first trajectory: {exec_time1}')
# Out:
# Execution time of first trajectory: 498.3810706138611

# %%
tmp = trajectory1[:, 1:3]

# %%
cTraj1 = correctedTraj1[:, 1:3]

# %%
avg_lat = np.mean([row[0] for row in tmp])
avg_lon = np.mean([row[1] for row in tmp])

# %%
m = folium.Map(
    location=[avg_lat, avg_lon],
    tiles="cartodbpositron",
    zoom_start=5
)

aline1 = folium.PolyLine(tmp, color='blue')
m.add_child(aline1)

aline2 = folium.PolyLine(cTraj1, color='red')
m.add_child(aline2)

# aline3 = folium.PolyLine(trajectory1[299:301, 1:3], color='green')
# m.add_child(aline3)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f882b98d39ffda19c35a0aaf8276f037 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f882b98d39ffda19c35a0aaf8276f037&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f882b98d39ffda19c35a0aaf8276f037 = L.map(
#                 &quot;map_f882b98d39ffda19c35a0aaf8276f037&quot;,
#                 {
#                     center: [38.05672619617225, 138.75973014354065],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9c4939aac10198765fcf88f99372317 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f882b98d39ffda19c35a0aaf8276f037);
#
#
#             var poly_line_96b80f30a982e995192eabe2b56a51b2 = L.polyline(
#                 [[42.455, 141.428], [42.4516, 141.4196], [42.4478, 141.4102], [42.4411, 141.3937], [42.436, 141.3808], [42.4341, 141.3763], [42.4285, 141.3623], [42.4237, 141.3503], [42.4186, 141.3378], [42.4123, 141.3223], [42.4081, 141.3118], [42.4022, 141.2975], [42.3976, 141.2859], [42.392, 141.2722], [42.3853, 141.2557], [42.3834, 141.2511], [42.3748, 141.2298], [42.3735, 141.2265], [42.3646, 141.206], [42.3588, 141.195], [42.351, 141.1826], [42.3458, 141.1754], [42.3408, 141.1689], [42.3266, 141.1525], [42.3185, 141.1432], [42.3091, 141.1326], [42.2984, 141.1204], [42.2957, 141.1173], [42.2843, 141.1044], [42.271, 141.0892], [42.2615, 141.0785], [42.2535, 141.0694], [42.2449, 141.0598], [42.2373, 141.0511], [42.2224, 141.0342], [42.2224, 141.0342], [42.2033, 141.0125], [42.2017, 141.0107], [42.1868, 140.9938], [42.1831, 140.9897], [42.1669, 140.9714], [42.159, 140.9625], [42.15, 140.9522], [42.144, 140.9455], [42.1364, 140.9368], [42.1209, 140.9195], [42.1129, 140.9105], [42.1074, 140.9046], [42.0926, 140.8904], [42.0872, 140.8858], [42.0743, 140.8754], [42.0659, 140.8694], [42.0507, 140.8594], [42.0384, 140.8523], [42.031, 140.8484], [42.0181, 140.8414], [42.012, 140.8382], [41.9993, 140.8313], [41.9892, 140.8259], [41.9781, 140.8199], [41.9655, 140.813], [41.9473, 140.8031], [41.9394, 140.7988], [41.9282, 140.7927], [41.9213, 140.7889], [41.9047, 140.7799], [41.8912, 140.7725], [41.8878, 140.7706], [41.8689, 140.7603], [41.8622, 140.7566], [41.853, 140.7516], [41.8381, 140.7434], [41.8293, 140.7386], [41.8118, 140.7291], [41.8075, 140.7268], [41.788, 140.7161], [41.7801, 140.7118], [41.7672, 140.7048], [41.7583, 140.7], [41.7481, 140.6945], [41.734, 140.6868], [41.7217, 140.6802], [41.7101, 140.6739], [41.7031, 140.6701], [41.6863, 140.661], [41.6771, 140.656], [41.6689, 140.6516], [41.6544, 140.6438], [41.6444, 140.6383], [41.6299, 140.6306], [41.6195, 140.6249], [41.6017, 140.6153], [41.5934, 140.6108], [41.5872, 140.6075], [41.5683, 140.5973], [41.5605, 140.5932], [41.549, 140.5869], [41.5416, 140.5828], [41.5222, 140.5721], [41.514, 140.5675], [41.5021, 140.5609], [41.4929, 140.5558], [41.4739, 140.5455], [41.4612, 140.5387], [41.4485, 140.5319], [41.4322, 140.5232], [41.4239, 140.5188], [41.4102, 140.5115], [41.3973, 140.5046], [41.3874, 140.4994], [41.3801, 140.4955], [41.3705, 140.4905], [41.3602, 140.485], [41.3488, 140.479], [41.3191, 140.4631], [41.3092, 140.4579], [41.2993, 140.4526], [41.2934, 140.4495], [41.2798, 140.4423], [41.2711, 140.4378], [41.2573, 140.4305], [41.2412, 140.4221], [41.2278, 140.415], [41.2173, 140.4095], [41.2024, 140.4016], [41.1909, 140.3954], [41.182, 140.3907], [41.1728, 140.3859], [41.1627, 140.3805], [41.1492, 140.3734], [41.1354, 140.3662], [41.1199, 140.3581], [41.1152, 140.3557], [41.1016, 140.3485], [41.0874, 140.3409], [41.0777, 140.3358], [41.0669, 140.3299], [41.0526, 140.3223], [41.0484, 140.3199], [41.0265, 140.3083], [41.0238, 140.3068], [41.0052, 140.297], [40.9995, 140.294], [40.9815, 140.2845], [40.9778, 140.2826], [40.9611, 140.2738], [40.9478, 140.2668], [40.9409, 140.2632], [40.9264, 140.2555], [40.9114, 140.2476], [40.9059, 140.2447], [40.8898, 140.2362], [40.8772, 140.2295], [40.8657, 140.2234], [40.8531, 140.2169], [40.8422, 140.2112], [40.8329, 140.2064], [40.822, 140.2009], [40.8139, 140.1968], [40.8016, 140.1906], [40.7877, 140.1833], [40.7803, 140.1796], [40.7696, 140.1741], [40.7507, 140.1642], [40.7414, 140.1594], [40.735, 140.156], [40.7233, 140.1498], [40.7087, 140.142], [40.7004, 140.1375], [40.6887, 140.1314], [40.68, 140.1267], [40.6607, 140.1166], [40.6566, 140.1144], [40.6483, 140.11], [40.626, 140.0982], [40.6165, 140.0932], [40.6067, 140.088], [40.5965, 140.0826], [40.5902, 140.0792], [40.5723, 140.07], [40.5646, 140.066], [40.5584, 140.0628], [40.5401, 140.0535], [40.5301, 140.0483], [40.5153, 140.0407], [40.5069, 140.0364], [40.4941, 140.0298], [40.4904, 140.0279], [40.4717, 140.0182], [40.466, 140.0153], [40.4579, 140.0111], [40.

# %%
aux_CalculateTrajectoryError(trajectory1, variablePoints)
# Out:
# 2.467576363506674

# %%
aux_CalculateTrajectoryError(correctedTraj1, variablePoints)
# Out:
# 0.7411546134172764

# %%
trajectory1[0]
# Out:
# array([1.6495488e+09, 4.2455000e+01, 1.4142800e+02, 6.1036200e+03])
